# %%
import pandas as pd

# %%
df = pd.read_csv("data/sales.csv")

# %%
df.head()
# Out:
#    order_id       customer     product  revenue
# 0      1001    Alice Smith      Laptop   1200.5
# 1      1002      Bob Jones  Smartphone    800.0
# 2      1003  Charlie Brown      Tablet    450.0
# 3      1004    Alice Smith  Headphones    150.0
# 4      1005   Diana Prince      Laptop   1200.5

# %%
df.dtypes
# Out:
# order_id      int64
# customer        str
# product         str
# revenue     float64
# dtype: object

# %%
df.shape
# Out:
# (15, 4)
